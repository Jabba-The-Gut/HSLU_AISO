# %% [markdown]
# # Minesweeper Puzzle

# %% [markdown]
# Lucerne University of Applied Sciences and Arts - School of Information Technology

# %% [markdown]
# The player is presented with a grid of squares. Some randomly selected squares, unknown to the player, contain mines. Other squares may display numbers indicating the count of mines present in the immediate neighborhood of the squares. Find all mines.
#
# See https://de.wikipedia.org/wiki/Minesweeper or go to http://minesweeperonline.com/ to play

# %% [markdown]
# Imports

# %%
from ortools.sat.python import cp_model
from itertools import product
import numpy as np

# %% [markdown]
# Some Minesweeper examples, the first one is from the lecture

# %%
mine_field1 = [
    ["2", "", "", "", "1"],
    ["2", "", "4", "3", ""],
    ["", "2", "", "1", ""],
    ["", "1", "", "3", ""],
    ["1", "", "", "", ""],
]
mine_field2 = [
    ["1", "", "", "", "2", "", "", "1"],
    ["", "1", "2", "", "3", "", "", "1"],
    ["", "2", "", "1", "", "", "", "0"],
    ["", "2", "1", "", "", "2", "3", "1"],
    ["", "", "", "2", "", "", "", ""],
    ["1", "", "", "", "4", "3", "", ""],
    ["", "1", "", "", "4", "", "3", ""],
    ["1", "", "", "2", "", "2", "", "1"],
]
mine_field3 = [
    ["", "", "", "", "", "1", "", ""],
    ["1", "2", "2", "1", "", "", "1", "1"],
    ["", "1", "", "", "", "", "", ""],
    ["", "", "0", "", "", "1", "", "1"],
    ["", "1", "", "", "", "", "", ""],
    ["", "", "1", "", "2", "3", "", ""],
    ["", "", "", "", "", "", "2", "1"],
    ["", "1", "", "2", "2", "", "2", ""],
]
mine_field4 = [
    ["1", "", "", "2", "", "2", "", "2", "", ""],
    ["", "3", "2", "", "", "", "4", "", "", "1"],
    ["", "", "", "1", "3", "", "", "", "4", ""],
    ["3", "", "1", "", "", "", "3", "", "", ""],
    ["", "2", "1", "", "1", "", "", "3", "", "2"],
    ["", "3", "", "2", "", "", "2", "", "1", ""],
    ["2", "", "", "3", "2", "", "", "2", "", ""],
    ["", "3", "", "", "", "3", "2", "", "", "3"],
    ["", "", "3", "", "3", "3", "", "", "", ""],
    ["", "2", "", "2", "", "", "", "", "2", ""],
]

# %% [markdown]
# Pick one of the examples

# %%
game = mine_field1

# %% [markdown]
# Create model

# %%
model = cp_model.CpModel()

# %%
# Out:
# None

# %%
board = [[model.NewBoolVar(str(c)) for c in range(len(game))] for i in range(len(game))]

# set all places where a number is to zero
for i in range(len(game)):
    for j in range(len(game)):
        if not game[i][j] == "":
            board[i][j] = 0
            

# calculate neighbour-cells
def neighbours(cell_y, cell_x):
    neighbours = []
    for y in range(cell_y-1, cell_y+2):
        for x in range(cell_x-1, cell_x+2):
            print(y,x)
            if not (y < 0 or y == len(game)) and not (x < 0 or x == len(game)) and not(cell_y == y and cell_x == x):
                neighbours.append((y,x))
    print(neighbours)

neighbours = neighbours(1,4)

# sum of neighbour-cells must be equal to number in cell
# Out:
# 0 0
# None
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-a9e38bbfe78f> in <module>
#      14             neighbour_cells = neighbours(i,j)
#      15             print(neighbour_cells)
# ---> 16             for cell in neighbour_cells:
#      17                 print(cell[0], cell[1])
#      18
#
# TypeError: 'NoneType' object is not iterable

# %% [markdown]
# Callback for solution printing

# %%
class SolutionPrinter(cp_model.CpSolverSolutionCallback):
    
    def __init__(self, variables, game):
        cp_model.CpSolverSolutionCallback.__init__(self)
        self.__variables = variables
        
    def on_solution_callback(self):
        for i in range(len(self.__variables)):
            for j in range(len(self.__variables)):
                if self.Value(self.__variables[i][j]) == 1:
                    print("[💣]\t", end='')
                elif game[i][j] == "":
                    print("[  ]\t", end='')
                else:
                    print("[ {}]\t".format(game[i][j]), end='')
            print("\n")
        print("\n\n")

# %% [markdown]
# Solve and print all solutions

# %%
solver = cp_model.CpSolver()
_ = solver.SearchForAllSolutions(model, SolutionPrinter(board, game))
# Out:
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# ...
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]
#
#
#
#
# [ 2]	[  ]	[  ]	[  ]	[ 1]
#
# [ 2]	[  ]	[ 4]	[ 3]	[  ]
#
# [  ]	[ 2]	[  ]	[ 1]	[  ]
#
# [  ]	[ 1]	[  ]	[ 3]	[  ]
#
# [ 1]	[  ]	[  ]	[  ]	[  ]

# %%
print(f"Runtime:   {solver.WallTime()}ms")
print(f"Booleans:  {solver.NumBooleans()}")
print(f"Failures:  {solver.NumConflicts()}")
print(f"Branches:  {solver.NumBranches()}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-99c10d473463> in <module>
# ----> 1 print(f"Runtime:   {solver.WallTime()}ms")
#       2 print(f"Booleans:  {solver.NumBooleans()}")
#       3 print(f"Failures:  {solver.NumConflicts()}")
#       4 print(f"Branches:  {solver.NumBranches()}")
#
# ~/.local/share/virtualenvs/AISO-NIF0zkfA/lib/python3.8/site-packages/ortools/sat/python/cp_model.py in WallTime(self)
#    1667     def WallTime(self):
#    1668         """Returns the wall time in seconds since the creation of the solver."""
# -> 1669         return self.__solution.wall_time
#    1670
#    1671     def UserTime(self):
#
# AttributeError: 'NoneType' object has no attribute 'wall_time'
